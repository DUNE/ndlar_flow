# %% [markdown]
# NOTE: This notebook uses a JSON dictionary created by the `ndlar_flow/scripts/low_level_data_ana/charge_data_feature_studies/adc_saturation/ADC_Saturation_Sample.py` script. As this notebook comprises of preliminary/diagnostic studies, the code may not be fully optimized. The code will be optimized in terms of runtime and organization as time permits. Please contact Elise Hinkle (ehinkle@uchicago.edu) with any questions, comments, or concerns. Also, all JSON dictionary file locations are likely outdated and should be changed based on where the user has chosen to store the relevant dictionary(ies).

# %%
# Import libraries and packages
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import h5py
import argparse
from datetime import datetime
import glob
import json
import cmasher as cmr
import math
import matplotlib as mpl
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.gridspec import GridSpec
import sys
import os
import sys
sys.path.append('/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/')
from lar2x2_evd import *
from collections import Counter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: IPython in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (8.20.0)
# Requirement already satisfied: decorator in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (2.17.2)
# Requirement already satisfied: stack-data in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (5.14.1)
# Requirement already satisfied: pexpect>4.3 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyMuPDF in /global/homes/e/ehinkle/.local/perlmutter/python-3.11/lib/python3.11/site-packages (1.24.8)
# Requirement already satisfied: PyMuPDFb==1.24.8 in /global/homes/e/ehinkle/.local/perlmutter/python-3.11/lib/python3.11/site-packages (from PyMuPDF) (1.24.8)
# Hello

# %%
# Define method to convert IO channel to tile number
def io_channel_to_tile(io_channel):
    return int(np.floor((io_channel-1-((io_channel-1)%4))/4+1))

# %%
# Open and refine dictionary (slight differences for different dictionary versions)

# Open dictionary with ADC Saturation BEAM events
adc_sat_file = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/adc_saturation_beam_events_dict.json'
adc_sat_open = open(adc_sat_file)
adc_sat_dict = json.load(adc_sat_open)

# Open dictionary with ADC Saturation BEAM events -- version of dictionary removing events with ADC saturation packets only coming from a few
# previously identified noisy chips/channels
adc_sat_file = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/adc_saturation_beam_events_V5_REMOVE_NOISY_PIXELS_dict.json'
adc_sat_open = open(adc_sat_file)
adc_sat_dict = json.load(adc_sat_open)

# Open dictionary with ADC Saturation BEAM events v3 (just sandbox -- trying to look at smaller sample with the newest version available at this time)
#adc_sat_file_V3_SANDBOX = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/adc_saturation_beam_events_V3_SANDBOX_dict.json'
#adc_sat_open_V3_SANDBOX = open(adc_sat_file_V3_SANDBOX)
#adc_sat_V3_SANDBOX_dict = json.load(adc_sat_open_V3_SANDBOX)

# Exclude LRS Low Threshold events (originally included full run in dictionary)
adc_sat_dict = {k: v for k, v in adc_sat_dict.items() if 'low_threshold' not in k}
print("Length of original dictionary: ", len(adc_sat_dict))
print("Length of dictionary after excluding LRS Low Threshold events: ", len(adc_sat_dict))
# Out:
# Length of original dictionary:  3917
# Length of dictionary after excluding LRS Low Threshold events:  3917
# [[[7, 1, 29, 41], [7, 1, 34, 60]], [[4, 10, 49, 12]], [[6, 20, 85, 38], [6, 20, 88, 37], [6, 20, 88, 38]], [[6, 9, 14, 12]], [[2, 13, 19, 32]], [[8, 17, 25, 34], [8, 17, 40, 59]], [[6, 17, 22, 37]], [[5, 7, 65, 52]], [[7, 12, 97, 59]], [[5, 7, 63, 17]], [[7, 11, 69, 11]], [[4, 17, 13, 61]], [[6, 25, 22, 47]], [[6, 6, 29, 7]], [[5, 22, 45, 7]], [[7, 26, 26, 43]], [[1, 18, 49, 32]], [[2, 19, 82, 48]], [[8, 3, 77, 36]], [[3, 20, 100, 44]], [[5, 32, 72, 46], [5, 32, 72, 48]], [[6, 2, 32, 37], [6, 2, 33, 37]], [[1, 28, 97, 59]], [[1, 26, 42, 14]], [[2, 29, 64, 43], [2, 29, 64, 44], [2, 29, 64, 45], [4, 26, 62, 49], [4, 26, 62, 51], [4, 26, 62, 59], [4, 26, 63, 51], [4, 26, 63, 53], [4, 26, 63, 59], [4, 26, 64, 49], [4, 26, 64, 53], [4, 26, 65, 16], [4, 26, 66, 18], [4, 26, 67, 26], [4, 26, 69, 33], [4, 26, 69, 35], [4, 30, 49, 36], [4, 30, 49, 41], [4, 30, 50, 33], [4, 30, 50, 34]], [[8, 12, 94, 20]], [[8, 6, 54, 61]], [[5, 7, 56, 7]], [[7, 1, 12, 46], [7, 12, 108, 63], [7, 13, 13, 52], [7, 13, 14, 52], [7, 13, 15, 62], [7, 13, 16, 60]], [[8, 11, 88, 61]], [[6, 20, 81, 44], [6, 20, 98, 59]], [[3, 28, 107, 58]], [[1, 15, 89, 21]], [[3, 13, 36, 46], [3, 13, 36, 47], [3, 13, 36, 48]], [[5, 4, 37, 20], [5, 4, 37, 41], [5, 4, 38, 21], [5, 4, 38, 22], [5, 4, 38, 42], [5, 4, 38, 43], [5, 7, 87, 7]], [[4, 10, 64, 4]], [[5, 22, 44, 4]], [[8, 28, 97, 42], [8, 28, 98, 44], [8, 28, 98, 45], [8, 28, 100, 42], [8, 29, 28, 53], [8, 29, 28, 60], [8, 29, 29, 44]], [[3, 19, 85, 46], [3, 19, 85, 48], [3, 19, 88, 46], [3, 19, 88, 49], [3, 19, 90, 51]], [[4, 11, 84, 63]], [[4, 6, 55, 58]], [[2, 11, 90, 0], [2, 15, 36, 53]], [[7, 23, 99, 52], [7, 23, 100, 49], [7, 23, 100, 51], [7, 29, 30, 44], [7, 29, 36, 60]], [[7, 27, 66, 62]], [[5, 2, 28, 27], [5, 2, 29, 35], [5, 2, 29, 36], [5, 2, 30, 27], [5, 2, 31, 62], [5, 4, 39, 58], [5, 4, 39, 59], [5, 4, 39, 60], [5, 7, 99, 7], [7, 7, 83, 43], [7, 7, 84, 18], [7, 7, 84, 26], [7, 7, 84, 36], [7, 7, 84, 37], [7, 7, 84, 41], [7, 7, 84, 43], [7, 7, 85, 26], [7, 7, 85, 27], [7, 7, 85, 43], [7, 7, 85, 45], [7, 7, 89, 43], [7, 7, 89, 44], [7, 7, 90, 21], [7, 7, 90, 42], [7, 7, 90, 43], [7, 7, 90, 47]], [[2, 29, 31, 37]], [[1, 5, 23, 62]], [[5, 12, 84, 58]], [[2, 7, 75, 2], [2, 7, 75, 5], [4, 3, 46, 42]], [[1, 17, 21, 29]], [[8, 16, 78, 16]], [[3, 1, 13, 50]], [[4, 13, 32, 63], [4, 13, 35, 60], [4, 13, 35, 61]], [[8, 24, 95, 41], [8, 24, 95, 45]], [[5, 24, 107, 36]], [[4, 18, 44, 48], [4, 22, 67, 33], [4, 22, 67, 34], [4, 22, 67, 35], [4, 22, 67, 41], [4, 23, 79, 60]], [[6, 3, 70, 57], [6, 3, 70, 58], [6, 7, 60, 37]], [[2, 14, 72, 46]], [[1, 10, 57, 2]], [[1, 25, 26, 59]], [[4, 32, 96, 35]], [[8, 6, 67, 52]], [[5, 24, 78, 52]], [[1, 2, 56, 35]], [[4, 25, 14, 32]], [[6, 5, 23, 49]], [[6, 15, 53, 48]], [[1, 8, 106, 61]], [[3, 21, 31, 47]], [[3, 10, 52, 28]], [[3, 31, 79, 29]], [[7, 5, 17, 29]], [[1, 10, 53, 21]], [[2, 15, 96, 11]], [[1, 15, 93, 41]], [[6, 12, 81, 62]], [[8, 14, 47, 26]], [[6, 32, 78, 22]], [[5, 32, 98, 34]], [[5, 29, 19, 51]], [[8, 5, 28, 0]], [[2, 15, 56, 59], [2, 19, 84, 60], [4, 11, 74, 59], [4, 11, 87, 49], [4, 11, 87, 53], [4, 11, 87, 59], [4, 11, 89, 43], [4, 11, 89, 44], [4, 11, 90, 42], [4, 11, 90, 43], [4, 13, 22, 46], [4, 13, 22, 48], [4, 13, 23, 45], [4, 13, 34, 15], [4, 13, 38, 59], [4, 13, 39, 53], [4, 13, 40, 42], [4, 13, 40, 50], [4, 13, 40, 59]], [[2, 26, 48, 59]], [[4, 9, 11, 35], [4, 9, 12, 28], [4, 9, 12, 29], [4, 9, 24, 4], [4, 9, 27, 43], [4, 9, 27, 44], [4, 9, 28, 36], [4, 9, 28, 41], [4, 9, 29, 19], [4, 9, 29, 34], [4, 15, 85, 52], [4, 15, 86, 48], [4, 15, 86, 50], [4, 15, 86, 53], [4, 15, 87, 17], [4, 15, 87, 46], [4, 15, 87, 48], [4, 15, 88, 45]], [[7, 26, 64, 27]], [[3, 18, 67, 11], [3, 18, 67, 50], [3, 18, 68, 12], [3, 18, 68, 50], [3, 18, 68, 53], [3, 18, 69, 49], [3, 18, 69, 50], [3, 22, 52, 42], [3, 22, 53, 43], [3, 22, 53, 44], [3, 22, 53, 45], [3, 22, 53, 46], [3, 22, 53, 47], [3, 22, 54, 42], [3, 22, 54, 46], [3, 22, 54, 52], [3, 22, 55, 44], [3, 22, 55, 46], [3, 22, 55 ...
# 15068
# Noisy channels:  [[ 2 17 21  4]
#  [ 2 17 21 13]]
# Number of noisy channels:  2
# 15068
# 525
# 2
# 0
# Noisy channels: [[ 2  5 21  4]
#  [ 2  5 21 13]]
# Number of noisy channels: 2
# (0.0, 60.0)

# %%
# SPECIFICALLY for ADC saturation packet dictionary including "noisy chips" (i.e. chips with more than 5 events with ADC saturation packets)
# HOWEVER, in addition to identifying noisy chips, this cell also defines certain variables used later in the notebook (i.e. unique_channels_with_adc_sat_packets)

# Get list of unique channels with ADC Saturation packets (using io channel and then network agnostic i.e. using tile number)
unique_channels_with_adc_sat_packets = [adc_sat_dict[k]['unique_channels_impacted'] for k in adc_sat_dict.keys()]
print(unique_channels_with_adc_sat_packets)
unique_channels_per_event = unique_channels_with_adc_sat_packets
unique_channels_with_adc_sat_packets = np.array([item for sublist in unique_channels_with_adc_sat_packets for item in sublist])
#print("Unique channels with ADC Saturation packets: ", unique_channels_with_adc_sat_packets[:20])
unique_channels_with_adc_sat_packets_network_agnostic = np.array([
    [channel[0], io_channel_to_tile(channel[1]), channel[2], channel[3]] for channel in unique_channels_with_adc_sat_packets
])
#print("Unique channels with ADC Saturation packets: ", unique_channels_with_adc_sat_packets_network_agnostic[:20])

# Identification of noisy channels
adc_sat_channels_ioch, adc_sat_channels_counts_ioch = np.unique(unique_channels_with_adc_sat_packets, axis=0, return_counts=True)
#print(len(adc_sat_channels_ioch))
noisy_channels_ioch = np.where(adc_sat_channels_counts_ioch>=5)
normal_channels_ioch = np.where(adc_sat_channels_counts_ioch<5)
print("Noisy channels: ", adc_sat_channels_ioch[noisy_channels_ioch]) 
print("Number of noisy channels: ", len(adc_sat_channels_ioch[noisy_channels_ioch]))
adc_sat_channels, adc_sat_channels_counts = np.unique(unique_channels_with_adc_sat_packets_network_agnostic, axis=0, return_counts=True)
#print(len(adc_sat_channels))
#print(len(adc_sat_channels_counts[adc_sat_channels_counts>1]))
#print(len(adc_sat_channels_counts[adc_sat_channels_counts>5]))
#print(len(adc_sat_channels_counts[adc_sat_channels_counts>100]))
noisy_channels = np.where(adc_sat_channels_counts>=5)
normal_channels = np.where(adc_sat_channels_counts<5)
print("Noisy channels:", adc_sat_channels[noisy_channels])
print("Number of noisy channels:", len(adc_sat_channels[noisy_channels]))

# Plot histogram of number of events with dataword==255 packets for each channel sending dataword==255 packets
plt.hist(adc_sat_channels_counts, bins=np.linspace(0, 1600, 321))
plt.yscale('log')
plt.ylabel('Number of Channels / 5 Events')
plt.xlabel('Number of Events with Dataword==255 Packets')
plt.title('Tracking the Number of Beam Events with Dataword==255 Packets\n for Each Channel Sending Dataword==255 Packets')
plt.xlim(0, 60)

# %%
# NOISY CHIP IDENTIFICATION AND REMOVAL FROM DICTIONARY
# This cell is mostly relevant for a version of the dictionary that includes "noisy chips" (i.e. chips with more than 5 events with ADC saturation packets)
# However, this cell is dependent on the "noisy chips" already being identified as such. For early 2x2 data (July 2024), the noisy chips are:
# 2/29/31, 6/7/99, 8/21/13, 2/17/21 (the latter is not included in this cell) -- these are listed by iogroup/iochannel/chip_id
# The current script (as of 2024-10-07) uses a version of the dictionary that has already removed events with ADC saturation packets only coming from noisy chips

#print(adc_sat_channels_ioch[noisy_channels_ioch].tolist())

print("Total number of unique channels:", len(adc_sat_channels))
print("Number of noisy channels:", len(adc_sat_channels[noisy_channels]))
# Filter noisy chips:
#print(adc_sat_channels)
noisy_chips = []
normal_chips = []
for i in range(len(adc_sat_channels)):
    if adc_sat_channels[i][0] == 2 and adc_sat_channels[i][1] == 8 and adc_sat_channels[i][2] == 31:
        noisy_chips.append(i)
        #print(adc_sat_channels[i])
    elif adc_sat_channels[i][0] == 6 and adc_sat_channels[i][1] == 2 and adc_sat_channels[i][2] == 99:
        noisy_chips.append(i)
        #print(adc_sat_channels[i])
    elif adc_sat_channels[i][0] == 8 and adc_sat_channels[i][1] == 6 and adc_sat_channels[i][2] == 13:
        noisy_chips.append(i)
        #print(adc_sat_channels[i])
    else:
        normal_chips.append(i)
print("Number of channels on noisy chips:", len(adc_sat_channels[noisy_chips]))
print("Number of channels on normal chips:", len(adc_sat_channels[normal_chips]))
print("Noisy chips channels:", len(adc_sat_channels_ioch[noisy_chips]))
print("Normal chips channels:", len(adc_sat_channels[normal_chips]))

print("Total number of unique channels:", len(adc_sat_channels_ioch))
print("Number of noisy channels:", len(adc_sat_channels_ioch[noisy_channels]))
# Filter noisy chips:
#print(adc_sat_channels)
noisy_chips_ioch = []
normal_chips_ioch = []
for i in range(len(adc_sat_channels_ioch)):
    if adc_sat_channels_ioch[i][0] == 2 and adc_sat_channels_ioch[i][1] == 29 and adc_sat_channels_ioch[i][2] == 31:
        noisy_chips_ioch.append(i)
        #print(adc_sat_channels[i])
    elif adc_sat_channels_ioch[i][0] == 6 and adc_sat_channels_ioch[i][1] == 7 and adc_sat_channels_ioch[i][2] == 99:
        noisy_chips_ioch.append(i)
        #print(adc_sat_channels[i])
    elif adc_sat_channels_ioch[i][0] == 8 and adc_sat_channels_ioch[i][1] == 21 and adc_sat_channels_ioch[i][2] == 13:
        noisy_chips_ioch.append(i)
        #print(adc_sat_channels[i])
    else:
        normal_chips_ioch.append(i)
print("Number of channels on noisy chips:", len(adc_sat_channels_ioch[noisy_chips_ioch]))
print("Number of channels on normal chips:", len(adc_sat_channels_ioch[normal_chips_ioch]))
print("Noisy chips channels:", len(adc_sat_channels_ioch[noisy_chips_ioch]))
print("Normal chips channels:", len(adc_sat_channels_ioch[normal_chips_ioch]))



# Check noisy channel on iog six
#print(adc_sat_channels[noisy_channels][0])
#for keys, values in adc_sat_dict.items():
#    #if not all(channel != chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch] for channel in values['unique_channels_impacted']):
#    #    print(keys)
#    #    print(values['unique_channels_impacted'])
#    if any(channel == chan.tolist() for chan in adc_sat_channels_ioch[normal_channels_ioch] for channel in values['unique_channels_impacted'])\
#    and any(channel == chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch] for channel in values['unique_channels_impacted']):
#        #print(keys)
#        print(values['unique_channels_impacted'])
    #if map(lambda x: not all(x in adc_sat_channels_ioch[noisy_channels_ioch].tolist()), values['unique_channels_impacted']):
     #   print(values['unique_channels_impacted'])
    #if all(chan.tolist() not in values['unique_channels_impacted'] for chan in adc_sat_channels[noisy_channels]):
    #for chan in adc_sat_channel_ioch[noisy_channels_ioch]:
    #    if chan.tolist() in values['unique_channels_impacted']:
    #        print(values['unique_channels_impacted'])

adc_sat_dict_remove_noisy_channels = {
    k: v for k, v in adc_sat_dict.items()
    if any(channel == chan.tolist() for chan in adc_sat_channels_ioch[normal_chips_ioch] for channel in v['unique_channels_impacted'])
   #if any(channel not in adc_sat_channels_ioch[noisy_channels_ioch].tolist() for channel in values['unique_channels_impacted'])
   #if all(channel != chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch] for channel in v['unique_channels_impacted']) 
    #if any(any(channel != chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch]) and any(channel == chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch]) for channel in values['unique_channels_impacted'])
    #if (not all(channel != chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch] for channel in v['unique_channels_impacted']) and any(channel == chan.tolist() for chan in adc_sat_channels_ioch[noisy_channels_ioch] for channel in v['unique_channels_impacted']))
    #if not any(all(channel == chan.tolist() for channel in v['unique_channels_impacted']) for chan in adc_sat_channels_ioch[noisy_channels_ioch])
}
#for keys, values in adc_sat_dict_remove_noisy_channels.items():
#    if [6,7,99,12] in values['unique_channels_impacted']:
    #print(keys)
    #print(values['unique_channels_impacted'])
    #if all(chan.tolist() not in values['unique_channels_impacted'] for chan in adc_sat_channels[noisy_channels]):
    #for chan in adc_sat_channels_ioch[noisy_channels_ioch]:
    #    if chan.tolist() in values['unique_channels_impacted']:
    #        print(values['unique_channels_impacted'])
#
# Out:
# Total number of unique channels: 15075
# Number of noisy channels: 55
# Number of channels on noisy chips: 69
# Number of channels on normal chips: 15006
# Noisy chips channels: 69
# Normal chips channels: 15006
# Total number of unique channels: 15075
# Number of noisy channels: 55
# Number of channels on noisy chips: 69
# Number of channels on normal chips: 15006
# Noisy chips channels: 69
# Normal chips channels: 15006

# %%
# Again, this cell is primarily concerned with refining the dictionary to remove events with ADC saturation packets only coming from noisy chips (or removing
# noisy chip packets from events with additional ADC saturation packets)

unique_channels_with_adc_sat_packets = [adc_sat_dict_remove_noisy_channels[k]['unique_channels_impacted'] for k in adc_sat_dict_remove_noisy_channels.keys()]
subkeys = []
for key, subdict in adc_sat_dict.items():
    subkeys.extend(subdict.keys())

print(subkeys)
#counts_unique_channels_with_adc_sat_packets = [adc_sat_dict_remove_noisy_channels[k]['total_sat_packets_per_unique_channel'] for k in adc_sat_dict_remove_noisy_channels.keys()]
unique_channels_with_adc_sat_packets = np.array([item for sublist in unique_channels_with_adc_sat_packets for item in sublist])
#counts_unique_channels_with_adc_sat_packets = np.array([item for sublist in counts_unique_channels_with_adc_sat_packets for item in sublist])
#print(counts_unique_channels_with_adc_sat_packets)
print("Number of events before noisy channels removed:", len(adc_sat_dict))
print("Number of events without just noisy channels:", len(adc_sat_dict_remove_noisy_channels))
# Out:
# ['event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath', 'timestamp', 'nhits', 'num_adc_saturation_packets', 'unique_channels_impacted', 'adc_sat_packets_per_unique_channel', 'is_beam', 'event_id', 'filepath ...
# Number of events before noisy channels removed: 5659
# Number of events without just noisy channels: 3810

# %%
# Again, this cell is primarily concerned with refining the dictionary to remove events with ADC saturation packets only coming from noisy chips (or removing
# noisy chip packets from events with additional ADC saturation packets)


#print("Total number of unique channels:", len(adc_sat_channels))
#print("Number of noisy channels:", len(adc_sat_channels[noisy_channels]))
## Filter noisy chips:
##print(adc_sat_channels)
#noisy_chips = []
#normal_chips = []
#for i in range(len(adc_sat_channels)):
#    if adc_sat_channels[i][0] == 2 and adc_sat_channels[i][1] == 8 and adc_sat_channels[i][2] == 31:
#        noisy_chips.append(i)
#        #print(adc_sat_channels[i])
#    elif adc_sat_channels[i][0] == 6 and adc_sat_channels[i][1] == 2 and adc_sat_channels[i][2] == 99:
#        noisy_chips.append(i)
#        #print(adc_sat_channels[i])
#    elif adc_sat_channels[i][0] == 8 and adc_sat_channels[i][1] == 6 and adc_sat_channels[i][2] == 13:
#        noisy_chips.append(i)
#        #print(adc_sat_channels[i])
#    else:
#        normal_chips.append(i)
#print("Number of channels on noisy chips:", len(adc_sat_channels[noisy_chips]))
#print("Number of channels on normal chips:", len(adc_sat_channels[normal_chips]))

# %%
# This cell is concerned with getting lists of main values for the dictionary (i.e. number of hits, number of ADC saturation packets, etc.) 
# This redundancy from above was necessary for previous use of the dictionary, but is not necessary for the current version of the dictionary
# as the newest dictionary by default exclude events with ADC saturation packets only coming from noisy chips.
# TODO: Remove this cell if not necessary and/or combine with cells above


# Get lists of main values: 
nhits_per_event = np.array([adc_sat_dict[k]['nhits'] for k in adc_sat_dict.keys()])
print(len(nhits_per_event))
n_adc_sat_packets_per_event = np.array([adc_sat_dict[k]['num_adc_saturation_packets'] for k in adc_sat_dict.keys()])
iog_with_adc_sat_packets = unique_channels_with_adc_sat_packets[:,0]
#print(unique_channels_per_event[:20])
iog_with_adc_sat_packets_per_event = [set([channel[0] for channel in unique_channels_per_event[i]]) for i in range(len(unique_channels_per_event))]
#print(iog_with_adc_sat_packets_per_event[20:34])
#print("IOG with ADC Saturation packets: ", iog_with_adc_sat_packets[:20])
iog_with_adc_sat_packets_counts_per_event = Counter(map(tuple, iog_with_adc_sat_packets_per_event))
#print(iog_with_adc_sat_packets_counts_per_event)
iog_combinations = [iog for iog in iog_with_adc_sat_packets_counts_per_event.keys()]
#print(iog_combinations)
iog_with_adc_sat_packets_counts = np.array([iog for iog in iog_with_adc_sat_packets_counts_per_event.values()])
#print(iog_with_adc_sat_packets_counts)

# list of main values without noisy channels:
#print(unique_channels_per_event[:20])
#print(adc_sat_channels[noisy_channels])
print(unique_channels_per_event[:10])
nhits_per_event_remove_noisy_channels = np.array([adc_sat_dict_remove_noisy_channels[k]['nhits'] for k in adc_sat_dict_remove_noisy_channels.keys()])
print(len(nhits_per_event_remove_noisy_channels))
n_adc_sat_packets_per_event_remove_noisy_channels = np.array([adc_sat_dict_remove_noisy_channels[k]['num_adc_saturation_packets'] for k in adc_sat_dict_remove_noisy_channels.keys()])

            
iog_with_adc_sat_packets_remove_noisy_channels = [set([channel[0] for channel in unique_channels_per_event[i] if any(channel == chan.tolist() for chan in adc_sat_channels_ioch[normal_chips_ioch])]) for i in range(len(unique_channels_per_event))]
channelid_with_adc_sat_packets_remove_noisy_channels = [[channel[3] for channel in unique_channels_per_event[i] if any(channel == chan.tolist() for chan in adc_sat_channels_ioch[normal_chips_ioch])] for i in range(len(unique_channels_per_event))]
iog_with_adc_sat_packets_counts_per_event_remove_noisy_channels = Counter(map(tuple, iog_with_adc_sat_packets_remove_noisy_channels))
print(iog_with_adc_sat_packets_counts_per_event_remove_noisy_channels)
# Out:
# 5659
# [[[7, 1, 29, 41], [7, 1, 34, 60]], [[4, 10, 49, 12]], [[6, 20, 85, 38], [6, 20, 88, 37], [6, 20, 88, 38]], [[6, 9, 14, 12]], [[2, 13, 19, 32]], [[8, 17, 25, 34], [8, 17, 40, 59]], [[6, 17, 22, 37]], [[5, 7, 65, 52]], [[7, 12, 97, 59]], [[5, 7, 63, 17]]]
# 3810
# Counter({(): 1849, (2,): 534, (1,): 527, (3,): 512, (4,): 458, (7,): 446, (5,): 409, (8,): 371, (6,): 305, (2, 4): 68, (1, 3): 51, (8, 6): 37, (5, 7): 32, (1, 2): 4, (5, 6): 4, (4, 7): 4, (1, 4): 4, (2, 7): 3, (6, 7): 3, (3, 4): 3, (4, 5): 3, (2, 3): 2, (5, 6, 7): 2, (8, 7): 2, (2, 3, 4): 2, (2, 5, 7): 2, (8, 5, 6): 2, (2, 6): 2, (4, 6): 2, (3, 7): 2, (8, 5, 7): 1, (3, 6): 1, (8, 1): 1, (1, 2, 3, 4): 1, (2, 5): 1, (8, 2): 1, (1, 5): 1, (1, 7): 1, (8, 2, 6): 1, (8, 2, 4): 1, (2, 6, 7): 1, (8, 5): 1, (8, 1, 6): 1, (8, 3): 1})

# %%
# Plot histograms of nhits per events and number of ADC saturation packets per event, and show pie chart of IOGs with ADC saturation packets

fig, axs = plt.subplots(3,1, figsize=(5,17))

max_nhits = math.ceil(max(nhits_per_event)/100)*100
min_nhits = math.floor(min(nhits_per_event)/100)*100
axs[0].hist(nhits_per_event, bins=int((max_nhits-min_nhits)/50), range=(min_nhits, max_nhits), color='b', alpha=0.5)
axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_title('Hits per Beam Event with Dataword==255 Packets')
axs[0].set_xlabel('Number of Hits')
axs[0].set_ylabel('Beam Event Count / 50 Hits')

max_adc_sat_packets = math.ceil(max(n_adc_sat_packets_per_event)/10)*10
min_adc_sat_packets = math.floor(min(n_adc_sat_packets_per_event)/10)*10
axs[1].hist(n_adc_sat_packets_per_event, bins=int((max_adc_sat_packets-min_adc_sat_packets)/10), range=(min_adc_sat_packets, max_adc_sat_packets), color='salmon', alpha=0.7)
axs[1].set_yscale('log')
axs[1].set_title('Dataword==255 Packets per Beam Event')
axs[1].set_xlabel('Number of Potential ADC Saturation Packets')
axs[1].set_ylabel('Beam Event Count / 10 Packets')

other_size = 0
labels= []
sizes = []
for key, value in iog_with_adc_sat_packets_counts_per_event.items():
    if len(key) > 1:
        other_size += value
    else:
        labels.append(str(key[0]))
        sizes.append(value)
if other_size > 0:
    labels.append('Multiple IOG')
    sizes.append(other_size)
axs[2].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
axs[2].axis('equal')
axs[2].set_title('ADC Saturation Packets IOGs by Event')
# Out:
# Text(0.5, 1.0, 'ADC Saturation Packets IOGs by Event')

# %%
# Plot histograms of nhits per events and number of ADC saturation packets per event, and show pie chart of IOGs with ADC saturation packets
# This cell is redundant with the previous cell if the original dictionary removed noisy chip packets


fig, axs = plt.subplots(3,1, figsize=(5,17))

max_nhits = math.ceil(max(nhits_per_event_remove_noisy_channels)/100)*100
min_nhits = math.floor(min(nhits_per_event_remove_noisy_channels)/100)*100
print(nhits_per_event_remove_noisy_channels[nhits_per_event_remove_noisy_channels>50000])
axs[0].hist(nhits_per_event_remove_noisy_channels, bins=int((max_nhits-min_nhits)/1000), range=(min_nhits, max_nhits), color='b', alpha=0.5)
axs[0].set_yscale('log')
axs[0].set_xscale('log')
axs[0].set_title('Hits per Beam Event with Beam Activity ADC Saturation Packets')
axs[0].set_xlabel('Number of Hits')
axs[0].set_ylabel('Beam Event Count / 1000 Hits')

max_adc_sat_packets = math.ceil(max(n_adc_sat_packets_per_event_remove_noisy_channels)/10)*10
min_adc_sat_packets = math.floor(min(n_adc_sat_packets_per_event_remove_noisy_channels)/10)*10
axs[1].hist(n_adc_sat_packets_per_event_remove_noisy_channels, bins=int((max_adc_sat_packets-min_adc_sat_packets)/10), range=(min_adc_sat_packets, max_adc_sat_packets), color='b', alpha=0.5)
axs[1].set_yscale('log')
axs[1].set_title('Beam Activity ADC Saturation Packets per Beam Event')
axs[1].set_xlabel('Number of Beam Activity ADC Saturation Packets')
axs[1].set_ylabel('Beam Event Count / 10 Packets')

other_size = 0
labels= ['', '', '', '', '', '', '', '', '']
sizes = np.zeros(9)
for key, value in iog_with_adc_sat_packets_counts_per_event_remove_noisy_channels.items():
    if len(key) > 1:
        other_size += value
    elif len(key) == 1:
        labels[9-key[0]]=str(key[0])
        sizes[9-key[0]]=value
    else:
        continue
if other_size > 0:
    labels[0] = 'Multiple'
    sizes[0] =other_size
print(labels)
print(sizes)
colors = ['darkgray', 'mediumorchid', 'violet', 'orange', 'gold',\
          'cornflowerblue', 'deepskyblue','mediumseagreen', 'lime']
axs[2].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
axs[2].axis('equal')
axs[2].set_title('Beam-Related ADC Saturation Packets IO Groups by Event')
# Out:
# [ 52917  68363  61119  50039  54062  57980  52330  56187 101622  56960
#   60871  60758  57964  51701  73604  54187  56953  50022  62382  65069
#   62368  59682  50107  61329  52673  59138]
# ['Multiple', '8', '7', '6', '5', '4', '3', '2', '1']
# [248. 371. 446. 305. 409. 458. 512. 534. 527.]
# Text(0.5, 1.0, 'Beam-Related ADC Saturation Packets IO Groups by Event')

# %%
# This cell is very exploratory and is not necessary for the main ADC Saturation packet analysis. It is used to identify events with ADC saturation packets
# which also include WTT. WTT is relatively uncommon in 2x2. To make a dictionary of 2x2 events with WTT, look in the whole_tile_triggering directory of 
# scripts/low_level_data_ana/charge_data_feature_studies. This cell saves dictionaries of events with ADC saturation removing WTT events.
how_many_events = 0
for k,v in adc_sat_dict_remove_noisy_channels.items():
    if v['num_adc_saturation_packets'] > 70:
        print(k, v['num_adc_saturation_packets'], np.unique(np.array(v['unique_channels_impacted'])[:,0]))
        how_many_events += 1
print("Number of events with more than 70 ADC Saturation packets: ", how_many_events)
full_tile_file = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/full_tile_trigger_dict.json'
full_tile_open = open(full_tile_file)
full_tile_trigger_dict = json.load(full_tile_open)

how_much_overlap = 0
beam_events_with_full_tile_trigger = 0
for k,v in full_tile_trigger_dict.items():
    if adc_sat_dict_remove_noisy_channels.get(k):
        #if not any(v['event_full_tile_spike']):
        #print(k, adc_sat_dict[k]['num_adc_saturation_packets'], np.unique(np.array(adc_sat_dict[k]['unique_channels_impacted'])[:,0]))
        how_much_overlap += 1

print("Number of events in ADC Saturation dict: ", len(adc_sat_dict_remove_noisy_channels))
print("Number of overlapping events: ", how_much_overlap)

adc_sat_dict_remove_noisy_channels_NOT_full_tile = {
    k: v for k, v in adc_sat_dict_remove_noisy_channels.items()
    if not full_tile_trigger_dict.get(k)
}
adc_sat_dict_remove_noisy_channels_full_tile_trigger = {
    k: v for k, v in adc_sat_dict_remove_noisy_channels.items()
    if full_tile_trigger_dict.get(k)
}
print("Number of events in ADC Saturation dict: ", len(adc_sat_dict_remove_noisy_channels))
print("Number of events in ADC Saturation dict NOT in full tile dict: ", len(adc_sat_dict_remove_noisy_channels_NOT_full_tile))
print("Number of events in ADC Saturation dict in full tile dict: ", len(adc_sat_dict_remove_noisy_channels_full_tile_trigger))


# list of main values without noisy channels:
# Out:
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_13_53_27_CDT.FLOW.hdf5-28656 82 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_12_15_51_CDT.FLOW.hdf5-1996 104 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_08_35_27_CDT.FLOW.hdf5-4058 89 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_10_00_27_09_CDT.FLOW.hdf5-2648 84 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_10_04_17_33_CDT.FLOW.hdf5-3977 156 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_04_04_58_CDT.FLOW.hdf5-5903 90 [1 3]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_17_56_27_CDT.FLOW.hdf5-7041 161 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_10_04_47_36_CDT.FLOW.hdf5-8 109 [6 8]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_01_14_40_CDT.FLOW.hdf5-61032 147 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_14_03_28_CDT.FLOW.hdf5-1612 196 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_00_34_36_CDT.FLOW.hdf5-66158 185 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_09_25_33_CDT.FLOW.hdf5-2288 135 [2 3 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_02_04_46_CDT.FLOW.hdf5-1278 87 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_00_24_35_CDT.FLOW.hdf5-27390 81 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_15_53_40_CDT.FLOW.hdf5-775 157 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_23_14_27_CDT.FLOW.hdf5-30583 83 [6]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_13_56_01_CDT.FLOW.hdf5-7858 187 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_16_13_42_CDT.FLOW.hdf5-33752 151 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_10_04_27_34_CDT.FLOW.hdf5-4118 146 [2 4]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_21_16_48_CDT.FLOW.hdf5-1371 137 [2]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_10_01_47_17_CDT.FLOW.hdf5-4065 261 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_09_16_36_19_CDT.FLOW.hdf5-5341 144 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_17_43_52_CDT.FLOW.hdf5-22394 82 [1 3]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july8_2024/nominal_hv/packet-0050017-2024_07_08_23_34_29_CDT.FLOW.hdf5-126 258 [5]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_14_29_17_CDT.FLOW.hdf5-1226 157 [3 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_12_03_10_39_CDT.FLOW.hdf5-3603 140 [1 3]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_10_14_06_42_CDT.FLOW.hdf5-983 187 [6 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_17_09_34_CDT.FLOW.hdf5-1159 126 [7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_12_03_30_41_CDT.FLOW.hdf5-3754 276 [6 8]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_20_49_58_CDT.FLOW.hdf5-2408 678 [6 8]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_12_01_10_26_CDT.FLOW.hdf5-1186 76 [5 7]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_15_59_27_CDT.FLOW.hdf5-3230 303 [6 8]
# /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_15_59_27_CDT.FLOW.hdf5-4092 117 [6]
# Number of events with more than 70 ADC Saturation packets:  33
# Number of events in ADC Saturation dict:  3810
# Number of overlapping events:  194
# Number of events in ADC Saturation dict:  3810
# Number of events in ADC Saturation dict NOT in full tile dict:  3616
# Number of events in ADC Saturation dict in full tile dict:  194

# %%
# This cell creates a method to make the plots above and runs this plotting method on multiple dictionary versions

def make_general_plots(dict_to_plot, title):

    nhits_per_event = np.array([dict_to_plot[k]['nhits'] for k in dict_to_plot.keys()])
   
    n_adc_sat_packets_per_event = np.array([dict_to_plot[k]['num_adc_saturation_packets'] for k in dict_to_plot.keys()])
    n_unique_channels_with_adc_sat_packets = [len(dict_to_plot[k]['unique_channels_impacted']) for k in dict_to_plot.keys()]
    iog_with_adc_sat_packets = [np.unique(np.array(v['unique_channels_impacted'])[:,0]) for v in dict_to_plot.values()]
    iog_with_adc_sat_packets_counts_per_event = Counter(map(tuple, iog_with_adc_sat_packets))

    fig, axs = plt.subplots(1,4, figsize=(23, 5))

    max_nhits = math.ceil(max(nhits_per_event)/100)*100
    min_nhits = math.floor(min(nhits_per_event)/100)*100
    
    axs[0].hist(nhits_per_event, bins=int((max_nhits-min_nhits)/50), range=(min_nhits, max_nhits), color='salmon', alpha=0.7)
    axs[0].set_yscale('log')
    axs[0].set_xscale('log')
    axs[0].set_title('Hits per Beam Event with Dataword==255 Packets')
    axs[0].set_xlabel('Number of Hits')
    axs[0].set_ylabel('Beam Event Count / 50 Hits')

    max_adc_sat_packets = math.ceil(max(n_adc_sat_packets_per_event)/10)*10
    min_adc_sat_packets = math.floor(min(n_adc_sat_packets_per_event)/10)*10
    axs[1].hist(n_adc_sat_packets_per_event, bins=int((max_adc_sat_packets-min_adc_sat_packets)/10), range=(min_adc_sat_packets, max_adc_sat_packets), color='salmon', alpha=0.7)
    axs[1].set_yscale('log')
    axs[1].set_title('Dataword==255 Packets per Beam Event')
    axs[1].set_xlabel('Number of Potential ADC Saturation Packets')
    axs[1].set_ylabel('Beam Event Count / 10 Packets')

    max_unique_channels_with_adc_sat_packets = math.ceil(max(n_unique_channels_with_adc_sat_packets)/10)*10
    min_unique_channels_with_adc_sat_packets = math.floor(min(n_unique_channels_with_adc_sat_packets)/10)*10
    axs[2].hist(n_adc_sat_packets_per_event, bins=int((max_unique_channels_with_adc_sat_packets-min_unique_channels_with_adc_sat_packets)/5), range=(min_unique_channels_with_adc_sat_packets, max_unique_channels_with_adc_sat_packets), color='salmon', alpha=0.7)
    axs[2].set_yscale('log')
    axs[2].set_title('Unique Channels with Dataword==255 Packets per Beam Event')
    axs[2].set_xlabel('Number of Unique Channels with Dataword==255 Packets')
    axs[2].set_ylabel('Beam Event Count / 5 Channels')

    other_size = 0
    labels= []
    sizes = []
    for key, value in iog_with_adc_sat_packets_counts_per_event.items():
        if len(key) > 1:
            other_size += value
        elif len(key) == 1:
            labels.append(str(key[0]))
            sizes.append(value)
        else:
            continue
    if other_size > 0:
        labels.append('Multiple IOG')
        sizes.append(other_size)
    axs[3].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    axs[3].axis('equal')
    axs[3].set_title('ADC Saturation Packets IOGs by Event')
    fig.suptitle(title)


make_general_plots(adc_sat_dict, 'All Beam Events with ADC Saturation Packets')
make_general_plots(adc_sat_dict_remove_noisy_channels, 'All Beam Events with ADC Saturation Packets (NO CHANNELS ON NOISY CHIPS)')
make_general_plots(adc_sat_dict_remove_noisy_channels_NOT_full_tile, 'All Beam Events with ADC Saturation Packets (NO CHANNELS ON NOISY CHIPS, NOT FULL TILE TRIGGER)')
make_general_plots(adc_sat_dict_remove_noisy_channels_full_tile_trigger, 'All Beam Events with ADC Saturation Packets (NO CHANNELS ON NOISY CHIPS, FULL TILE TRIGGER)')

# %%
# This cell attempts to identify events with very low and very high rates of ADC saturation packets.

#for keys, values in adc_sat_dict_remove_noisy_channels.items():
#    print(keys)
#    print(values['unique_channels_impacted'])
adc_sat_dict_few_adc_sat_packets = {
    k: v for k, v in adc_sat_dict_remove_noisy_channels.items()
    if v['num_adc_saturation_packets'] <= 10
}
adc_sat_dict_many_adc_sat_packets = {
    k: v for k, v in adc_sat_dict_remove_noisy_channels.items()
    if v['num_adc_saturation_packets'] > 5
}
print("Small hits:", len(adc_sat_dict_few_adc_sat_packets))
print("Large hits:", len(adc_sat_dict_many_adc_sat_packets))
# Out:
# Small hits: 3585
# Large hits: 373

# %%
# This cell allows for the creation of a PDF showing events with ADC saturation with the relevant hits highlighted 
# (i.e. plotted over the event display with a blue X marker)

output_pdf_name = 'adc_saturation_beam_events_not_noise_second_200.pdf'
with PdfPages(output_pdf_name, keep_empty=False) as output:
    counter = 0
    for keys, values in adc_sat_dict_remove_noisy_channels.items():
        counter += 1
        #if counter < 101: continue
        if counter > 2: break
        file = values['filepath'].split('/')[-1]
        directory = values['filepath'].split('packet')[0]
        directory = directory.replace('v1', 'v4')
        print("Directory:", directory)
        ev_id = values['event_id']

        evd = LArEventDisplay(filedir=directory, filename=file, nhits=values['nhits']-1, ntrigs=0, show_light=False, show_colorbars=False, beam_only=True)
        hits, cmap, charge_norm = evd.display_event(ev_id)
        print("ADC Sat Hits:", len(hits[hits['Q']>245]))
        sat_hits = hits[hits['Q']>245]
        print("ADC Sat Packets:", values['num_adc_saturation_packets'])
        #print("File:", file)
        #print("Directory:", directory)
        #print("Event ID:", ev_id)
        evd.ax_bdv.scatter(sat_hits['z'], sat_hits['x'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x', label=values['num_adc_saturation_packets'])
        evd.ax_bd.scatter(sat_hits['z'], sat_hits['x'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_bv.scatter(sat_hits['z'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_dv.scatter(sat_hits['x'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_bdv.legend(title='Number of Dataword==255 Packets')
        output.savefig(bbox_inches='tight')
        plt.close()
# Out:
# Number of available events: 127
# For fast-forwarding purposes, here is every 10th event number in your sample: [970, 1639, 2082, 2789, 3296, 3929, 4413, 4837, 5965, 6935, 7521, 8012]
# Number of external triggers in this event: 1
# External trigger information: [5] [4963419.] [4963419]
# Event 7840 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 6
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1023927.] [1023927]
# Event 8146 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 73
# For fast-forwarding purposes, here is every 10th event number in your sample: [1269, 2303, 3413, 4378, 5014, 5730, 6457]
# Number of external triggers in this event: 1
# External trigger information: [5] [7684113.] [7684113]
# Event 333 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 47
# For fast-forwarding purposes, here is every 10th event number in your sample: [2142, 3413, 4899, 5627]
# Number of external triggers in this event: 1
# External trigger information: [5] [1642855.] [1642855]
# Event 433 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9619887.] [9619887]
# Event 495 is a beam trigger event
# ADC Sat Hits: 7
# ADC Sat Packets: 7
# Number of available events: 18
# For fast-forwarding purposes, here is every 10th event number in your sample: [4726]
# Number of external triggers in this event: 1
# External trigger information: [5] [735683.] [735683]
# Event 1269 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 36
# For fast-forwarding purposes, here is every 10th event number in your sample: [2344, 3533, 5345]
# Number of external triggers in this event: 1
# External trigger information: [5] [8005789.] [8005789]
# Event 3150 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 16
# For fast-forwarding purposes, here is every 10th event number in your sample: [4814]
# Number of external triggers in this event: 1
# External trigger information: [5] [5013433.] [5013433]
# Event 4343 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 5
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [4077250.] [4077250]
# Event 5831 is a beam trigger event
# ADC Sat Hits: 24
# ADC Sat Packets: 24
# Number of available events: 62
# For fast-forwarding purposes, here is every 10th event number in your sample: [1513, 2995, 4343, 5014, 5730, 6721]
# Number of external triggers in this event: 1
# External trigger information: [5] [6659872.] [6659872]
# Event 6297 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 56
# For fast-forwarding purposes, here is every 10th event number in your sample: [1599, 3150, 4726, 5300, 5943]
# Number of external triggers in this event: 1
# External trigger information: [5] [7234885.] [7234885]
# Event 6851 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 108
# For fast-forwarding purposes, here is every 10th event number in your sample: [786, 1773, 2395, 3020, 3980, 4659, 5270, 5797, 6467, 7162]
# Number of external triggers in this event: 1
# External trigger information: [5] [9343915.] [9343915]
# Event 2051 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 33
# For fast-forwarding purposes, here is every 10th event number in your sample: [2489, 5060, 7200]
# Number of external triggers in this event: 1
# External trigger information: [5] [1925006.] [1925006]
# Event 2489 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 18
# For fast-forwarding purposes, here is every 10th event number in your sample: [4900]
# Number of external triggers in this event: 1
# External trigger information: [5] [5844489.] [5844489]
# Event 2814 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 13
# For fast-forwarding purposes, here is every 10th event number in your sample: [5281]
# Number of external triggers in this event: 1
# External trigger information: [5] [2390103.] [2390103]
# Event 3240 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 134
# For fast-forwarding purposes, here is every 10th event number in your sample: [696, 1412, 1915, 2603, 3240, 3881, 4454, 4900, 5315, 5826, 6410, 6989, 7346]
# Number of external triggers in this event: 1
# External trigger information: [5] [373674.] [373674]
# Event 3291 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 69
# For fast-forwarding purposes, here is every 10th event number in your sample: [1366, 2489, 3339, 4861, 5408, 6836]
# Number of external triggers in this event: 1
# External trigger information: [5] [805252.] [805252]
# Event 4168 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 6
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [39457.] [39457]
# Event 5281 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 128
# For fast-forwarding purposes, here is every 10th event number in your sample: [712, 1479, 1932, 2739, 3310, 4110, 4659, 5230, 5516, 6137, 6882, 7215]
# Number of external triggers in this event: 1
# External trigger information: [5] [6478373.] [6478373]
# Event 6137 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [3194938.] [3194938]
# Event 1228 is a beam trigger event
# ADC Sat Hits: 3
# ADC Sat Packets: 3
# Number of available events: 6
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9191982.] [9191982]
# Event 1552 is a beam trigger event
# ADC Sat Hits: 6
# ADC Sat Packets: 6
# Number of available events: 257
# For fast-forwarding purposes, here is every 10th event number in your sample: [189, 442, 679, 1040, 1245, 1536, 1924, 2163, 2410, 2717, 2947, 3239, 3665, 3865, 4165, 4838, 5013, 5367, 5673, 6006, 6301, 6613, 7058, 7371, 7762]
# Number of external triggers in this event: 1
# External trigger information: [5] [5170613.] [5170613]
# Event 1773 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7822106.] [7822106]
# Event 1996 is a beam trigger event
# ADC Sat Hits: 104
# ADC Sat Packets: 104
# Number of available events: 35
# For fast-forwarding purposes, here is every 10th event number in your sample: [1255, 2731, 5403]
# Number of external triggers in this event: 1
# External trigger information: [5] [4573080.] [4573080]
# Event 2731 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 9
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9260909.] [9260909]
# Event 3924 is a beam trigger event
# ADC Sat Hits: 3
# ADC Sat Packets: 3
# Number of available events: 15
# For fast-forwarding purposes, here is every 10th event number in your sample: [3924]
# Number of external triggers in this event: 1
# External trigger information: [5] [8597010.] [8597010]
# Event 5330 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 5
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [2578375.] [2578375]
# Event 5775 is a beam trigger event
# ADC Sat Hits: 69
# ADC Sat Packets: 69
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [2646611.] [2646611]
# Event 7803 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 60
# For fast-forwarding purposes, here is every 10th event number in your sample: [1155, 1996, 3097, 4821, 6428, 7935]
# Number of external triggers in this event: 1
# External trigger information: [5] [644030.] [644030]
# Event 7862 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 17
# For fast-forwarding purposes, here is every 10th event number in your sample: [3794]
# Number of external triggers in this event: 1
# External trigger information: [5] [9517135.] [9517135]
# Event 2725 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 26
# For fast-forwarding purposes, here is every 10th event number in your sample: [2996, 4989]
# Number of external triggers in this event: 1
# External trigger information: [5] [3559817.] [3559817]
# Event 2996 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 235
# For fast-forwarding purposes, here is every 10th event number in your sample: [290, 654, 1010, 1254, 1659, 1930, 2271, 2789, 3170, 3662, 3894, 4293, 4618, 4943, 5190, 5467, 5689, 6033, 6327, 6595, 6841, 7230, 7500]
# Number of external triggers in this event: 1
# External trigger information: [5] [1566637.] [1566637]
# Event 3054 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1557682.] [1557682]
# Event 4058 is a beam trigger event
# ADC Sat Hits: 89
# ADC Sat Packets: 89
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1525907.] [1525907]
# Event 4293 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 28
# For fast-forwarding purposes, here is every 10th event number in your sample: [2996, 4959]
# Number of external triggers in this event: 1
# External trigger information: [5] [9517781.] [9517781]
# Event 4602 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 22
# For fast-forwarding purposes, here is every 10th event number in your sample: [3794, 5637]
# Number of external triggers in this event: 1
# External trigger information: [5] [3518256.] [3518256]
# Event 4636 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 9
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7535033.] [7535033]
# Event 4943 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9536205.] [9536205]
# Event 4959 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 16
# For fast-forwarding purposes, here is every 10th event number in your sample: [4058]
# Number of external triggers in this event: 1
# External trigger information: [5] [3538301.] [3538301]
# Event 4989 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 20
# For fast-forwarding purposes, here is every 10th event number in your sample: [3794, 7487]
# Number of external triggers in this event: 1
# External trigger information: [5] [7596364.] [7596364]
# Event 6141 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [2948773.] [2948773]
# Event 1991 is a beam trigger event
# ADC Sat Hits: 9
# ADC Sat Packets: 9
# Number of available events: 51
# For fast-forwarding purposes, here is every 10th event number in your sample: [1252, 2268, 3957, 5865, 6908]
# Number of external triggers in this event: 1
# External trigger information: [5] [1944345.] [1944345]
# Event 322 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 266
# For fast-forwarding purposes, here is every 10th event number in your sample: [210, 530, 861, 1108, 1306, 1613, 1859, 2205, 2498, 2835, 3194, 3453, 3800, 4059, 4272, 4532, 4764, 5032, 5258, 5529, 5796, 6102, 6371, 6562, 6833, 7119]
# Number of external triggers in this event: 1
# External trigger information: [5] [3941922.] [3941922]
# Event 346 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 8
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9868730.] [9868730]
# Event 807 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 256
# For fast-forwarding purposes, here is every 10th event number in your sample: [246, 577, 920, 1144, 1370, 1685, 1982, 2292, 2631, 2920, 3302, 3590, 3924, 4117, 4410, 4675, 4903, 5119, 5440, 5715, 5948, 6271, 6457, 6756, 7055]
# Number of external triggers in this event: 1
# External trigger information: [5] [5852262.] [5852262]
# Event 1144 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 5
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9848822.] [9848822]
# Event 1252 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [3850239.] [3850239]
# Event 1497 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7851848.] [7851848]
# Event 1531 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [6095019.] [6095019]
# Event 4307 is a beam trigger event
# ADC Sat Hits: 2
# ADC Sat Packets: 2
# Number of available events: 22
# For fast-forwarding purposes, here is every 10th event number in your sample: [1531, 6534]
# Number of external triggers in this event: 1
# External trigger information: [5] [2778389.] [2778389]
# Event 5865 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 71
# For fast-forwarding purposes, here is every 10th event number in your sample: [1005, 1895, 3359, 4231, 5235, 6189, 6908]
# Number of external triggers in this event: 1
# External trigger information: [5] [4938623.] [4938623]
# Event 6271 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 247
# For fast-forwarding purposes, here is every 10th event number in your sample: [264, 630, 1005, 1216, 1497, 1776, 2107, 2409, 2765, 3127, 3453, 3800, 4059, 4307, 4579, 4797, 5077, 5364, 5644, 5904, 6257, 6439, 6739, 7008]
# Number of external triggers in this event: 1
# External trigger information: [5] [989824.] [989824]
# Event 6384 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [3655624.] [3655624]
# Event 758 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7334490.] [7334490]
# Event 1972 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 109
# For fast-forwarding purposes, here is every 10th event number in your sample: [557, 1034, 1591, 2341, 3123, 3886, 4178, 4576, 5349, 6450]
# Number of external triggers in this event: 1
# External trigger information: [5] [6310843.] [6310843]
# Event 2710 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 5
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9410422.] [9410422]
# Event 3736 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9248987.] [9248987]
# Event 5287 is a beam trigger event
# ADC Sat Hits: 37
# ADC Sat Packets: 37
# Number of available events: 38
# For fast-forwarding purposes, here is every 10th event number in your sample: [1304, 3736, 4604]
# Number of external triggers in this event: 1
# External trigger information: [5] [4666055.] [4666055]
# Event 6841 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 105
# For fast-forwarding purposes, here is every 10th event number in your sample: [1284, 2523, 3379, 4055, 4836, 5506, 6075, 6510, 7279, 8230]
# Number of external triggers in this event: 1
# External trigger information: [5] [7452664.] [7452664]
# Event 1345 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 10
# For fast-forwarding purposes, here is every 10th event number in your sample: [8471]
# Number of external triggers in this event: 1
# External trigger information: [5] [3883462.] [3883462]
# Event 2204 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9779531.] [9779531]
# Event 2584 is a beam trigger event
# ADC Sat Hits: 4
# ADC Sat Packets: 4
# Number of available events: 60
# For fast-forwarding purposes, here is every 10th event number in your sample: [2204, 3515, 5163, 6075, 6741, 8740]
# Number of external triggers in this event: 1
# External trigger information: [5] [5759699.] [5759699]
# Event 2651 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 43
# For fast-forwarding purposes, here is every 10th event number in your sample: [2523, 5163, 6137, 7915]
# Number of external triggers in this event: 1
# External trigger information: [5] [8297434.] [8297434]
# Event 3085 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 48
# For fast-forwarding purposes, here is every 10th event number in your sample: [2523, 5010, 6090, 7084]
# Number of external triggers in this event: 1
# External trigger information: [5] [225860.] [225860]
# Event 3379 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 121
# For fast-forwarding purposes, here is every 10th event number in your sample: [1210, 2156, 3015, 3591, 4188, 4836, 5506, 5911, 6376, 6862, 7807, 8685]
# Number of external triggers in this event: 1
# External trigger information: [5] [2722351.] [2722351]
# Event 4224 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 12
# For fast-forwarding purposes, here is every 10th event number in your sample: [6137]
# Number of external triggers in this event: 1
# External trigger information: [5] [1155340.] [1155340]
# Event 5163 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7147105.] [7147105]
# Event 5292 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7855380.] [7855380]
# Event 5589 is a beam trigger event
# ADC Sat Hits: 10
# ADC Sat Packets: 10
# Number of available events: 7
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [5869908.] [5869908]
# Event 5650 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 56
# For fast-forwarding purposes, here is every 10th event number in your sample: [2416, 3683, 5589, 6137, 7318]
# Number of external triggers in this event: 1
# External trigger information: [5] [7970726.] [7970726]
# Event 6075 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 14
# For fast-forwarding purposes, here is every 10th event number in your sample: [5817]
# Number of external triggers in this event: 1
# External trigger information: [5] [3984706.] [3984706]
# Event 6118 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 93
# For fast-forwarding purposes, here is every 10th event number in your sample: [1441, 2651, 3591, 4700, 5313, 5911, 6464, 7125, 8299]
# Number of external triggers in this event: 1
# External trigger information: [5] [5571504.] [5571504]
# Event 6980 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [2393033.] [2393033]
# Event 7915 is a beam trigger event
# ADC Sat Hits: 16
# ADC Sat Packets: 16
# Number of available events: 62
# For fast-forwarding purposes, here is every 10th event number in your sample: [2204, 3399, 5010, 5984, 6590, 8471]
# Number of external triggers in this event: 1
# External trigger information: [5] [6410321.] [6410321]
# Event 8031 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 58
# For fast-forwarding purposes, here is every 10th event number in your sample: [837, 2698, 4557, 5483, 6264]
# Number of external triggers in this event: 1
# External trigger information: [5] [8238102.] [8238102]
# Event 837 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [3556461.] [3556461]
# Event 2397 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 51
# For fast-forwarding purposes, here is every 10th event number in your sample: [991, 2798, 4744, 5944, 7268]
# Number of external triggers in this event: 1
# External trigger information: [5] [4028401.] [4028401]
# Event 3579 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 111
# For fast-forwarding purposes, here is every 10th event number in your sample: [438, 991, 2075, 2766, 3523, 4077, 4813, 5516, 6164, 6642, 7306]
# Number of external triggers in this event: 1
# External trigger information: [5] [4613551.] [4613551]
# Event 4035 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 56
# For fast-forwarding purposes, here is every 10th event number in your sample: [911, 2766, 4702, 5516, 6427]
# Number of external triggers in this event: 1
# External trigger information: [5] [1609965.] [1609965]
# Event 5516 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 5
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7578794.] [7578794]
# Event 5714 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 74
# For fast-forwarding purposes, here is every 10th event number in your sample: [582, 1711, 2798, 4077, 5205, 5927, 7165]
# Number of external triggers in this event: 1
# External trigger information: [5] [5571356.] [5571356]
# Event 5774 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 251
# For fast-forwarding purposes, here is every 10th event number in your sample: [336, 606, 854, 1164, 1547, 1948, 2270, 2576, 2826, 3115, 3332, 3588, 3951, 4279, 4702, 4941, 5205, 5516, 5757, 6142, 6321, 6613, 6890, 7123, 7349]
# Number of external triggers in this event: 1
# External trigger information: [5] [6666895.] [6666895]
# Event 6831 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 234
# For fast-forwarding purposes, here is every 10th event number in your sample: [336, 606, 854, 1164, 1547, 1990, 2289, 2617, 2910, 3168, 3429, 3783, 4035, 4413, 4837, 5078, 5502, 5743, 6153, 6452, 6677, 7080, 7285]
# Number of external triggers in this event: 1
# External trigger information: [5] [4630070.] [4630070]
# Event 6953 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 9
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [9294771.] [9294771]
# Event 479 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 19
# For fast-forwarding purposes, here is every 10th event number in your sample: [1907]
# Number of external triggers in this event: 1
# External trigger information: [5] [7751315.] [7751315]
# Event 1401 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 14
# For fast-forwarding purposes, here is every 10th event number in your sample: [2614]
# Number of external triggers in this event: 1
# External trigger information: [5] [2999576.] [2999576]
# Event 1907 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 107
# For fast-forwarding purposes, here is every 10th event number in your sample: [543, 895, 1319, 1555, 1912, 2395, 2770, 3070, 3824, 4130]
# Number of external triggers in this event: 1
# External trigger information: [5] [2984428.] [2984428]
# Event 2197 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 20
# For fast-forwarding purposes, here is every 10th event number in your sample: [1907, 4200]
# Number of external triggers in this event: 1
# External trigger information: [5] [9609153.] [9609153]
# Event 2346 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 63
# For fast-forwarding purposes, here is every 10th event number in your sample: [826, 1401, 1986, 2593, 3304, 4147]
# Number of external triggers in this event: 1
# External trigger information: [5] [9298623.] [9298623]
# Event 3735 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1833204.] [1833204]
# Event 4147 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [7664726.] [7664726]
# Event 114 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 29
# For fast-forwarding purposes, here is every 10th event number in your sample: [944, 1913]
# Number of external triggers in this event: 1
# External trigger information: [5] [9670342.] [9670342]
# Event 222 is a beam trigger event
# ADC Sat Hits: 3
# ADC Sat Packets: 3
# Number of available events: 80
# For fast-forwarding purposes, here is every 10th event number in your sample: [459, 944, 1383, 1809, 2326, 2977, 3478, 4075]
# Number of external triggers in this event: 1
# External trigger information: [5] [4367618.] [4367618]
# Event 431 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 47
# For fast-forwarding purposes, here is every 10th event number in your sample: [650, 1430, 2025, 3287]
# Number of external triggers in this event: 1
# External trigger information: [5] [866140.] [866140]
# Event 1048 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 11
# For fast-forwarding purposes, here is every 10th event number in your sample: [2698]
# Number of external triggers in this event: 1
# External trigger information: [5] [9461057.] [9461057]
# Event 1209 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 94
# For fast-forwarding purposes, here is every 10th event number in your sample: [459, 924, 1209, 1649, 1913, 2326, 2821, 3318, 3859]
# Number of external triggers in this event: 1
# External trigger information: [5] [3079795.] [3079795]
# Event 2209 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [5804377.] [5804377]
# Event 2493 is a beam trigger event
# ADC Sat Hits: 3
# ADC Sat Packets: 3
# Number of available events: 95
# For fast-forwarding purposes, here is every 10th event number in your sample: [459, 924, 1209, 1649, 1913, 2326, 2821, 3287, 3824]
# Number of external triggers in this event: 1
# External trigger information: [5] [599290.] [599290]
# Event 3010 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [5241310.] [5241310]
# Event 3287 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1
# Number of available events: 40
# For fast-forwarding purposes, here is every 10th event number in your sample: [876, 1540, 2473, 3973]
# Number of external triggers in this event: 1
# External trigger information: [5] [9213516.] [9213516]
# Event 3340 is a beam trigger event
# ADC Sat Hits: 1
# ADC Sat Packets: 1

# %%
# This cell allows for the creation of a PDF showing events with ADC saturation with the relevant hits highlighted 
# (i.e. plotted over the event display with a blue X marker). The section commented out also plots events with negative charge hits from ADC drift

output_pdf_name = 'adc_saturation_beam_events_negative_charge_JUST_EVENTS.pdf'
with PdfPages(output_pdf_name, keep_empty=False) as output:
    counter = 0
    for keys, values in adc_sat_dict_remove_noisy_channels.items():
        counter += 1
        #if counter < 101: continue
        if counter > 10: break
        file = values['filepath'].split('/')[-1]
        directory = values['filepath'].split('packet')[0]
        ev_id = values['event_id']

        evd = LArEventDisplay(filedir=directory, filename=file, nhits=values['nhits']-1, ntrigs=0, show_light=False, show_colorbars=True, beam_only=True)
        hits, cmap, charge_norm = evd.display_event(ev_id)
        #print("ADC Sat Hits:", len(hits[hits['Q']<0]))
        #negative_charge_hits = hits[hits['Q']<0]
        #print("ADC Sat Packets:", values['num_adc_saturation_packets'])
        ##print("File:", file)
        ##print("Directory:", directory)
        ##print("Event ID:", ev_id)
        #evd.ax_bdv.scatter(negative_charge_hits['z'], negative_charge_hits['x'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*', label=len(negative_charge_hits))
        #evd.ax_bd.scatter(negative_charge_hits['z'], negative_charge_hits['x'], c='aqua', s=25, alpha=0.50, marker='*')
        #evd.ax_bv.scatter(negative_charge_hits['z'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*')
        #evd.ax_dv.scatter(negative_charge_hits['x'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*')
        #evd.ax_bdv.legend(title='Number of Charge < 0 Hits')
        output.savefig(bbox_inches='tight')
        plt.close()
# Out:
# Number of available events: 9
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [6536418.] [6536418]
# Event 9 is a beam trigger event
# Number of available events: 65
# For fast-forwarding purposes, here is every 10th event number in your sample: [445, 1270, 1777, 2410, 2797, 3746]
# Number of external triggers in this event: 1
# External trigger information: [5] [5189709.] [5189709]
# Event 273 is a beam trigger event
# Number of available events: 4
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1658720.] [1658720]
# Event 1000 is a beam trigger event
# Number of available events: 25
# For fast-forwarding purposes, here is every 10th event number in your sample: [1331, 2640]
# Number of external triggers in this event: 1
# External trigger information: [5] [7696044.] [7696044]
# Event 2534 is a beam trigger event
# Number of available events: 8
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [1661298.] [1661298]
# Event 2587 is a beam trigger event
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [8176896.] [8176896]
# Event 2797 is a beam trigger event
# Number of available events: 33
# For fast-forwarding purposes, here is every 10th event number in your sample: [1241, 2390, 3174]
# Number of external triggers in this event: 1
# External trigger information: [5] [8101928.] [8101928]
# Event 2924 is a beam trigger event
# Number of available events: 26
# For fast-forwarding purposes, here is every 10th event number in your sample: [1331, 2640]
# Number of external triggers in this event: 1
# External trigger information: [5] [2669515.] [2669515]
# Event 3127 is a beam trigger event
# Number of available events: 2
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# External trigger information: [5] [8942501.] [8942501]
# Event 3797 is a beam trigger event
# Number of available events: 38
# For fast-forwarding purposes, here is every 10th event number in your sample: [1411, 3799, 5506]
# Number of external triggers in this event: 1
# External trigger information: [5] [2456263.] [2456263]
# Event 1538 is a beam trigger event

# %%
# This cell allows for the creation of a PDF showing events with ADC saturation with the relevant hits highlighted 
# (i.e. plotted over the event display with a blue X marker). Negative charge hits from ADC drift are also plotted with a cyan asterisk
# while PDF savefig lines are commented, the event displays will be shown in the notebook. 

#output_pdf_name = 'full_tile_trig_events_negative_charge_hits_and_adc_sat_packets.pdf'
output_pdf_name = 'adc_sat_V4_negative_charge_hits_and_adc_sat_packets.pdf'
with PdfPages(output_pdf_name, keep_empty=False) as output:
    counter = 0
    for keys, values in adc_sat_dict_remove_noisy_channels.items():
        counter += 1
        if counter < 16: continue
        if counter > 30: break
        if counter%10 == 0: print('--------------- LOOKING AT EVENT NUMBER: ', counter, '---------------')
        file = values['filepath'].split('/')[-1]
        directory = values['filepath'].split('packet')[0]
        directory = directory.replace('v1', 'v4')
        print("Directory:", directory)
        ev_id = values['event_id']

        evd = LArEventDisplay(filedir=directory, filename=file, nhits=values['nhits']-1, ntrigs=0, show_light=False, show_colorbars=True, beam_only=True)
        hits_ini, cmap_ini, charge_norm_ini = evd.display_event(ev_id)
        #output.savefig(bbox_inches='tight')
        #plt.close()
        hits, cmap, charge_norm = evd.display_event(ev_id)
        f = h5py.File(directory+file,'r')
        events = f['charge/events/data']
        event_mask = events['id'] == ev_id
        event = events[event_mask]
        hits_ref = f['charge/events/ref/charge/calib_prompt_hits/ref']
        hits_region = f['charge/events/ref/charge/calib_prompt_hits/ref_region']
        packets_full = f['charge/packets/data']
        packets_ref = f['charge/calib_prompt_hits/ref/charge/packets/ref']
        packets_hit_ref = f['charge/calib_prompt_hits/ref/charge/packets/ref']
        hit_ref = hits_ref[hits_region[ev_id,'start']:hits_region[ev_id,'stop']]
        hit_ref = np.sort(hit_ref[hit_ref[:,0] == ev_id, 1])
        packet_ref = packets_ref[hit_ref]
        packet_ref = np.sort(packet_ref[:, 1])
        packets = packets_full[packet_ref]
        adc_sat_idx = np.where(packets['packet_type']==0) and np.where(packets['dataword']==255)
        adc_sat_hits_ref = np.sort(packets_hit_ref[:,0][adc_sat_idx])
        sat_hits = hits[adc_sat_hits_ref]
        negative_charge_hits = hits[hits['Q']<0]
        #sat_hits = hits[hits['Q']>245]
        evd.ax_bdv.scatter(negative_charge_hits['z'], negative_charge_hits['x'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*', label=str(len(negative_charge_hits))+' Negative Charge Hits')
        evd.ax_bd.scatter(negative_charge_hits['z'], negative_charge_hits['x'], c='aqua', s=25, alpha=0.50, marker='*')
        evd.ax_bv.scatter(negative_charge_hits['z'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*')
        evd.ax_dv.scatter(negative_charge_hits['x'], negative_charge_hits['y'], c='aqua', s=25, alpha=0.50, marker='*')
        evd.ax_bdv.scatter(sat_hits['z'], sat_hits['x'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x', label=str(len(sat_hits))+' Dataword==255 Packets')
        evd.ax_bd.scatter(sat_hits['z'], sat_hits['x'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_bv.scatter(sat_hits['z'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_dv.scatter(sat_hits['x'], sat_hits['y'], c='royalblue', s=25, alpha=0.70, marker='x')
        evd.ax_bdv.legend()
        #output.savefig(bbox_inches='tight')
        #plt.close()
# Out:
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 73
# For fast-forwarding purposes, here is every 10th event number in your sample: [924, 1627, 3062, 4004, 4815, 5822, 6856]
# Number of external triggers in this event: 1
# Event 4324 is a beam trigger event
# Number of available events: 73
# For fast-forwarding purposes, here is every 10th event number in your sample: [924, 1627, 3062, 4004, 4815, 5822, 6856]
# Number of external triggers in this event: 1
# Event 4324 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 110
# For fast-forwarding purposes, here is every 10th event number in your sample: [670, 1352, 1678, 2823, 3526, 4160, 4690, 5260, 6102, 6421, 6951]
# Number of external triggers in this event: 1
# Event 5043 is a beam trigger event
# Number of available events: 110
# For fast-forwarding purposes, here is every 10th event number in your sample: [670, 1352, 1678, 2823, 3526, 4160, 4690, 5260, 6102, 6421, 6951]
# Number of external triggers in this event: 1
# Event 5043 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 54
# For fast-forwarding purposes, here is every 10th event number in your sample: [1218, 2823, 3992, 5219, 6623]
# Number of external triggers in this event: 1
# Event 5219 is a beam trigger event
# Number of available events: 54
# For fast-forwarding purposes, here is every 10th event number in your sample: [1218, 2823, 3992, 5219, 6623]
# Number of external triggers in this event: 1
# Event 5219 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 30
# For fast-forwarding purposes, here is every 10th event number in your sample: [2162, 4974, 6951]
# Number of external triggers in this event: 1
# Event 5347 is a beam trigger event
# Number of available events: 30
# For fast-forwarding purposes, here is every 10th event number in your sample: [2162, 4974, 6951]
# Number of external triggers in this event: 1
# Event 5347 is a beam trigger event
# --------------- LOOKING AT EVENT NUMBER:  20 ---------------
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 55
# For fast-forwarding purposes, here is every 10th event number in your sample: [1218, 2823, 3992, 5219, 6603]
# Number of external triggers in this event: 1
# Event 5643 is a beam trigger event
# Number of available events: 55
# For fast-forwarding purposes, here is every 10th event number in your sample: [1218, 2823, 3992, 5219, 6603]
# Number of external triggers in this event: 1
# Event 5643 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 19
# For fast-forwarding purposes, here is every 10th event number in your sample: [2864]
# Number of external triggers in this event: 1
# Event 6787 is a beam trigger event
# Number of available events: 19
# For fast-forwarding purposes, here is every 10th event number in your sample: [2864]
# Number of external triggers in this event: 1
# Event 6787 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 8
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 171 is a beam trigger event
# Number of available events: 8
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 171 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 24
# For fast-forwarding purposes, here is every 10th event number in your sample: [1744, 4435]
# Number of external triggers in this event: 1
# Event 951 is a beam trigger event
# Number of available events: 24
# For fast-forwarding purposes, here is every 10th event number in your sample: [1744, 4435]
# Number of external triggers in this event: 1
# Event 951 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 7
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 985 is a beam trigger event
# Number of available events: 7
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 985 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 1346 is a beam trigger event
# Number of available events: 3
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 1346 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 14
# For fast-forwarding purposes, here is every 10th event number in your sample: [3960]
# Number of external triggers in this event: 1
# Event 1373 is a beam trigger event
# Number of available events: 14
# For fast-forwarding purposes, here is every 10th event number in your sample: [3960]
# Number of external triggers in this event: 1
# Event 1373 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 30
# For fast-forwarding purposes, here is every 10th event number in your sample: [1346, 3453, 6858]
# Number of external triggers in this event: 1
# Event 1494 is a beam trigger event
# Number of available events: 30
# For fast-forwarding purposes, here is every 10th event number in your sample: [1346, 3453, 6858]
# Number of external triggers in this event: 1
# Event 1494 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 16
# For fast-forwarding purposes, here is every 10th event number in your sample: [2786]
# Number of external triggers in this event: 1
# Event 2235 is a beam trigger event
# Number of available events: 16
# For fast-forwarding purposes, here is every 10th event number in your sample: [2786]
# Number of external triggers in this event: 1
# Event 2235 is a beam trigger event
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 2768 is a beam trigger event
# Number of available events: 1
# For fast-forwarding purposes, here is every 10th event number in your sample: []
# Number of external triggers in this event: 1
# Event 2768 is a beam trigger event
# --------------- LOOKING AT EVENT NUMBER:  30 ---------------
# Directory: /global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july8_2024/nominal_hv/
# Number of available events: 27
# For fast-forwarding purposes, here is every 10th event number in your sample: [1373, 3960]
# Number of external triggers in this event: 1
# Event 3861 is a beam trigger event
# Number of available events: 27
# For fast-forwarding purposes, here is every 10th event number in your sample: [1373, 3960]
# Number of external triggers in this event: 1
# Event 3861 is a beam trigger event

# %%
# This cell was exploratory in its attempt to identify other patterns in events with ADC saturation packets. It is not necessary for the main analysis.

#for keys, values in adc_sat_dict.items():
#    if values['adc_sat_packets_iog'] == [1,8]:
#        print(keys)

#file = '/global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v1/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_12_29_05_CDT.FLOW.hdf5'
#ev_id = 2944
file = '/global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/REFLOW/v4/beam/july10_2024/nominal_hv/packet-0050018-2024_07_11_08_08_37_CDT.FLOW.hdf5'
ev_id = 3572

with h5py.File(file, 'r') as f:
    
    print(f['charge'].keys())
    events = f['charge/events/data']
    hits_full = f['charge/calib_prompt_hits/data']
    hits_ref = f['charge/events/ref/charge/calib_prompt_hits/ref']
    hits_region = f['charge/events/ref/charge/calib_prompt_hits/ref_region']
    packets_full = f['charge/packets/data']
    packets_ref = f['charge/calib_prompt_hits/ref/charge/packets/ref']

    event_mask = events['id'] == ev_id
    event = events[event_mask]
    hit_ref = hits_ref[hits_region[ev_id,'start']:hits_region[ev_id,'stop']]
    hit_ref = np.sort(hit_ref[hit_ref[:,0] == ev_id, 1])
    hits = hits_full[hit_ref]
    packet_ref = packets_ref[hit_ref]
    packet_ref = np.sort(packet_ref[:, 1])
    packets_event = packets_full[packet_ref]

    dict_key = file+'-'+str(ev_id)
    unique_channels_with_adc_sat_packets = adc_sat_dict[dict_key]['unique_channels_impacted']
    print("Unique channels with ADC Saturation packets: ", unique_channels_with_adc_sat_packets)
 
    for chan in unique_channels_with_adc_sat_packets:
        io_group_mask = packets_event['io_group'] == chan[0]
        packets = packets_event[io_group_mask]
        io_channel_mask = packets['io_channel'] == chan[1]
        packets = packets[io_channel_mask]
        chip_id_mask = packets['chip_id'] == chan[2]
        packets = packets[chip_id_mask]
        channel_id_mask = packets['channel_id'] == chan[3]
        packets = packets[channel_id_mask]
        plt.scatter(packets['timestamp'], packets['dataword'], label="Packets", color='blue')

        adc_sat_idx = np.where(
            (packets_event['io_group'] == chan[0]) &
            (packets_event['io_channel'] == chan[1]) &
            (packets_event['chip_id'] == chan[2]) &
            (packets_event['channel_id'] == chan[3])
        )        
        print(packets_event[adc_sat_idx])
        adc_sat_hits_ref = np.sort(packets_ref[:,0][adc_sat_idx])
        adc_sat_hits = hits[adc_sat_hits_ref]
        print(adc_sat_hits.dtype.names)
        plt.scatter(adc_sat_hits['ts_pps'], adc_sat_hits['Q'], label='Hits', color='red')
        plt.legend()
        print("Hit yz:", adc_sat_hits['y'], adc_sat_hits['z'])
        print("Hit Q:", adc_sat_hits['Q'])
# Out:
# <KeysViewHDF5 ['calib_final_hits', 'calib_prompt_hits', 'events', 'ext_trigs', 'packets', 'packets_corr_ts', 'raw_events', 'raw_hits']>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 30
#      27 packets_event = packets_full[packet_ref]
#      29 dict_key = file+'-'+str(ev_id)
# ---> 30 unique_channels_with_adc_sat_packets = adc_sat_dict[dict_key]['unique_channels_impacted']
#      31 print("Unique channels with ADC Saturation packets: ", unique_channels_with_adc_sat_packets)
#      33 for chan in unique_channels_with_adc_sat_packets:
#
# NameError: name 'adc_sat_dict' is not defined

# %%
# This cell was exploratory in terms of its use to look at a different dictionary created to look at all datawords recorded in 2x2
# It is not necessary for the main study of ADC saturation packets and requires an additional dictionary to be created. I leave it here for completeness, but
# I suggest recreating such a dictionary for more detailed study if this line of inquiry is pursued.

all_dw_file = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/all_datawords_dict.json'
all_dw_open = open(all_dw_file)
all_dw_dict = json.load(all_dw_open)

possible_dw = np.linspace(0, 256, 257)
dw_counts = np.zeros(256)
#print(possible_dw)
for key, value in all_dw_dict.items():
    for i in range(len(all_dw_dict[key]['datawords'])):
        #print(all_dw_dict[key]['datawords'][i])
        #print(all_dw_dict[key]['dw_counts'][i])
        dw_counts[all_dw_dict[key]['datawords'][i]] += all_dw_dict[key]['dw_counts'][i]
plt.figure(figsize=(15, 6))
#plt.yscale('log')
plt.xlabel('Dataword')
plt.ylabel('Number of Packets / Dataword')
plt.title('Dataword Distribution in all 2x2 Beam Events')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.hist(possible_dw[:-1], bins=possible_dw, weights=dw_counts, color='red', alpha=0.9)
#plt.axvline(255, color='red', linestyle='dashed')
#plt.axvline(0, color='red', linestyle='dashed')
plt.xlim(0, 256)
print(len(dw_counts[250]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 23
#      20 #plt.axvline(255, color='red', linestyle='dashed')
#      21 #plt.axvline(0, color='red', linestyle='dashed')
#      22 plt.xlim(0, 256)
# ---> 23 print(len(dw_counts[250]))
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
#print(100*(sum(dw_counts[251:])/sum(dw_counts)))
# Out:
# 0.018168266827256196
