# %% [markdown]
# # LArEventDisplay Example

# %% [markdown]
# #### LArEventDisplay is the 2x2 event display class defined in lar_only_evd.py which uses datasets from `proto_nd_flow`-ed files.

# %%
import sys
sys.path.append('/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/')
from lar2x2_evd import *
plt.ion()
# Out:
# Hello

# %% [markdown]
# #### Inputs to LArEventDisplay:
#
# - `filedir`       (str): path to input file
# - `filename`      (str): name of file; must be flow file run through `proto_nd_flow`
# - `nhits`         (int): hit threshold for events to be made available in interactive display (default=1)
# - `ntrigs`        (int): minimum number of external triggers required for events to be made available in interactive display (default=0)
# - `show_light`    (bool): whether to show light information in display (default: True, but this takes longer to run)

# %%
# This set of inputs allows you to look at a data file from July 2, 2024
#directory = '/global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/beam/july2_2024/ramp_hv_morcs/'
#file = 'packet-0050004-2024_07_02_14_22_35_CDT.FLOW.hdf5'
#directory = '/global/cfs/cdirs/dune/www/data/2x2/nearline/flowed_charge/beam/july7_2024/half_nominal_hv/'
#file = 'packet-0050011-2024_07_07_13_09_28_CDT.FLOW.hdf5'
directory = '/global/cfs/cdirs/dune/users/calivers/marjolein_files/'
file = 'combined_2024_07_07_11_19_15_CDT.with_ref.FLOW.hdf5'

# You should be able to keep these two lines as is OR you can change them to reflect where the logos
# live in your ndlar-flow directory 
logodune = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/DUNElogo.png'
logo2x2 = '/global/cfs/cdirs/dune/users/ehinkle/nd_prototypes_ana/2x2_sim/run-ndlar-flow/ndlar_flow/event_display/LAr_evd/2x2logo.png'

# %% [markdown]
# #### Running the following cell will show the event display and a user input box. User input options are:
#
#  - `q`+`Enter`       : quit the event display
#  - `s`+`Enter`       : save current event display to a PDF
#  - `Enter` : proceed to the next available event (may not be next event ID number if `nhits` > 1)
#  - `n`+`Enter` : proceed to the `n`th available event (may not correspond with event ID number if `nhits` > 1)

# %%
evd = LArEventDisplay(filedir=directory, filename=file, dune_logo=logodune, subexp_logo=logo2x2, nhits=400, ntrigs=1, show_light=True)

evd.run()
# Out:
# Charge Unix TS: 1720369156
# Charge TS Start: 5867401.0
# Charge TS End: 5871153.0
# Light matches: [ 8  9 10 11 12 13 30 31 32 33 34 35]
# Light unix timestamp: [[1720369155533 1720369155533 1720369155533 1720369155533 1720369155533
#   1720369155533 1720369155533 1720369155533]
#  [1720369155610 1720369155610 1720369155610 1720369155610 1720369155610
#   1720369155610 1720369155610 1720369155610]
#  [1720369155623 1720369155623 1720369155623 1720369155623 1720369155623
#   1720369155623 1720369155623 1720369155623]
#  [1720369155634 1720369155634 1720369155634 1720369155634 1720369155634
#   1720369155634 1720369155634 1720369155634]
#  [1720369155648 1720369155648 1720369155648 1720369155648 1720369155648
#   1720369155648 1720369155648 1720369155648]
#  [1720369155669 1720369155669 1720369155669 1720369155669 1720369155669
#   1720369155669 1720369155669 1720369155669]
#  [1720369156497 1720369156497 1720369156497 1720369156497 1720369156497
#   1720369156497 1720369156497 1720369156497]
#  [1720369156560 1720369156560 1720369156560 1720369156560 1720369156560
#   1720369156560 1720369156560 1720369156560]
#  [1720369156570 1720369156570 1720369156570 1720369156570 1720369156570
#   1720369156570 1720369156570 1720369156570]
#  [1720369156590 1720369156590 1720369156590 1720369156590 1720369156590
#   1720369156590 1720369156590 1720369156590]
#  [1720369156627 1720369156627 1720369156627 1720369156627 1720369156627
#   1720369156627 1720369156627 1720369156627]
#  [1720369156643 1720369156643 1720369156643 1720369156643 1720369156643
#   1720369156643 1720369156643 1720369156643]]
# Light time since PPS: [[1720369176530365184 1720369176530365184 1720369176530365184
#   1720369176530365184 1720369176530365184 1720369176530365184
#   1720369176530365184 1720369176530365184]
#  [1720369176607541504 1720369176607541504 1720369176607541504
#   1720369176607541504 1720369176607541504 1720369176607541504
#   1720369176607541504 1720369176607541504]
#  [1720369176618698496 1720369176618698496 1720369176618698496
#   1720369176618698496 1720369176618698496 1720369176618698496
#   1720369176618698496 1720369176618698496]
#  [1720369176630915584 1720369176630915584 1720369176630915584
#   1720369176630915584 1720369176630915584 1720369176630915584
#   1720369176630915584 1720369176630915584]
#  [1720369176644706048 1720369176644706048 1720369176644706048
#   1720369176644706048 1720369176644706048 1720369176644706048
#   1720369176644706048 1720369176644706048]
#  [1720369176665775360 1720369176665775360 1720369176665775360
#   1720369176665775360 1720369176665775360 1720369176665775360
#   1720369176665775360 1720369176665775360]
#  [1720369177492252928 1720369177492252928 1720369177492252928
#   1720369177492252928 1720369177492252928 1720369177492252928
#   1720369177492252928 1720369177492252928]
#  [1720369177558161920 1720369177558161920 1720369177558161920
#   1720369177558161920 1720369177558161920 1720369177558161920
#   1720369177558161920 1720369177558161920]
#  [1720369177567368960 1720369177567368960 1720369177567368960
#   1720369177567368960 1720369177567368960 1720369177567368960
#   1720369177567368960 1720369177567368960]
#  [1720369177586739968 1720369177586739968 1720369177586739968
#   1720369177586739968 1720369177586739968 1720369177586739968
#   1720369177586739968 1720369177586739968]
#  [1720369177623747840 1720369177623747840 1720369177623747840
#   1720369177623747840 1720369177623747840 1720369177623747840
#   1720369177623747840 1720369177623747840]
#  [1720369177634861568 1720369177634861568 1720369177634861568
#   1720369177634861568 1720369177634861568 1720369177634861568
#   1720369177634861568 1720369177634861568]]
# Number of available events: 499
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
