# %% [markdown]
# # Module0FlowEventDisplay Example

# %% [markdown]
# #### Module0FlowEventDisplay is the single module event display class defined in module0flow_evd.py which uses datasets from `module0_flow`-ed files.

# %%
from module0flow_evd import *
plt.ion()

# %% [markdown]
# #### Inputs to Module0FlowEventDisplay:
#
# - `filedir`       (str): path to input file
# - `filename`      (str): name of file; must be flow file run through `module0_flow`
# - `geometry_file` (str): full path and name of geometry file describing module to be displayed
# - `nhits`         (int): hit threshold for events to be made available in interactive display (default=1)

# %%
# This set of inputs allows you to look at a Module1 charge-only file
# This file originates from the same raw data file as the input file in the ProtoNDFlowEventDisplay example
directory = '/global/cfs/cdirs/dune/www/data/Module1/reco/charge_only/'
file = 'events_2022_02_09_17_23_09_CET.gz.h5'
geometry = '/global/cfs/cdirs/dune/www/data/Module1/TPC12/module1_layout-2.3.16.yaml'

# %% [markdown]
# #### Running the following cell will show the event display and a user input box. User input options are:
#
#  - `q`+`Enter`       : quit the event display
#  - `s`+`Enter`       : save current event display to a PDF
#  - `Enter` : proceed to the next available event (may not be next event ID number if `nhits` > 1)
#  - `n`+`Enter` : proceed to the `n`th available event (may not correspond with event ID number if `nhits` > 1)

# %%
evd = Module0FlowEventDisplay(filedir=directory, filename=file, geometry_file=geometry,nhits=1)
evd.run()
# Out:
# Next event (q to exit/s to save to pdf/enter for next/number to skip to position)?
#  q
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /global/common/software/nersc/pe/conda-envs/23.9.0/python-3.11/nersc-python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
